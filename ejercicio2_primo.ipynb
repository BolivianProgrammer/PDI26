# %% [markdown]
# # Ejercicio 2: Número Primo
# Determina si un número introducido por teclado es primo o no.

# %%
def es_primo(n):
    if n < 2:
        return False
    if n == 2:
        return True
    if n % 2 == 0:
        return False
    for i in range(3, int(n ** 0.5) + 1, 2):
        if n % i == 0:
            return False
    return True

try:
    numero = int(input("Ingrese un número entero: "))
    if es_primo(numero):
        print(f"{numero} ES un número primo.")
    else:
        print(f"{numero} NO es un número primo.")
except ValueError:
    print("Por favor, ingrese un número entero válido.")
# Out:
# 10 NO es un número primo.

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

img = cv2.imread('pencils.jpg')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
fig, axs = plt.subplots(1, 4, figsize=(20, 5))
axs[0].imshow(img_rgb)
axs[0].set_title('Original Image')

fig_img = axs[1].imshow(img_rgb[..., 0], cmap='gray')
fig.colorbar(fig_img, ax=axs[1], shrink=0.5)
axs[1].set_title('Red Channel')

fig_img = axs[2].imshow(img_rgb[..., 1], cmap='gray')
fig.colorbar(fig_img, ax=axs[2], shrink=0.5)
axs[2].set_title('Green Channel')

fig_img = axs[3].imshow(img_rgb[..., 2], cmap='gray')
fig.colorbar(fig_img, ax=axs[3], shrink=0.5)
axs[3].set_title('Blue Channel')
# Out:
# Text(0.5, 1.0, 'Blue Channel')

# %%
img_rgb[:3,:3,:]
# Out:
# array([[[203, 207, 210],
#         [208, 212, 215],
#         [211, 215, 218]],
#
#        [[201, 205, 208],
#         [207, 211, 214],
#         [211, 215, 218]],
#
#        [[202, 206, 209],
#         [209, 213, 216],
#         [212, 216, 219]]], dtype=uint8)

# %%
plt.imshow(img_rgb[:800,:1200,:])

# %%
cv2.imwrite('pencils.jpg', img_rgb)
plt.imsave('new_pencils.jpg', cv2.cvtColor(img_rgb, cv2.COLOR_RGB2BGR))

# %% [markdown]
# Ejercicios para generar imagenes

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['figure.figsize'] = [10,5]
size_image = 100
R = np.ones((size_image, size_image)) * 255
G = np.ones((size_image, size_image)) * 128
B = np.ones((size_image, size_image)) * 0

imagen = np.dstack((R,G,B))
imagen = np.array(imagen, dtype = int)

plt.figure()
plt.imshow(imagen)
plt.title('Homemade image')
plt.show()

# %%
import cv2 
import matplotlib.pyplot as plt
import numpy as np
img = cv2.imread('pencils.jpg', cv2.IMREAD_GRAYSCALE)
original = img.dtype
img16bits = np.uint16(img)
img_new = img16bits.dtype
print('Profundidad del color: ', img_new)

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.title('Original image')
plt.imshow(img, cmap='gray')
plt.imsave('bw_pencils.jpg', cv2.cvtColor(img_rgb, cv2.COLOR_RGB2BGR))

plt.subplot(1,2,2)
plt.title('16 bit image')
plt.imshow(img, cmap='gray')
plt.imsave('16bit_newpencils.jpg', cv2.cvtColor(img_rgb, cv2.COLOR_RGB2BGR))
# Out:
# Profundidad del color:  uint16
